# %%
import pandas as pd

# %%
all_data = pd.read_csv('./data/final_data.csv')

# %%
all_data
# Out:
#       Unnamed: 0               area  rank_gs  \
# 0              0  3D Reconstruction      9.0
# 1              1  3D Reconstruction     68.0
# 2              2  3D Reconstruction     95.0
# 3              3  3D Reconstruction     30.0
# 4              4  3D Reconstruction     33.0
# ...          ...                ...      ...
# 8250        9095   Super-Resolution    401.0
# 8251        9096   Super-Resolution    401.0
# 8252        9098   Super-Resolution    401.0
# 8253        9099   Super-Resolution    401.0
# 8254        9100   Super-Resolution    401.0
#
#                                                   title  rate_gs  rank_pc  \
# 0     occupancy networks: learning 3d reconstruction...      5.0     18.0
# 1     weakly supervised 3d reconstruction with adver...      4.0      4.0
# 2     infinitam v3: a framework for large-scale 3d r...      4.0     17.0
# 3     pix2vox: context-aware 3d reconstruction from ...      5.0     45.0
# ...
